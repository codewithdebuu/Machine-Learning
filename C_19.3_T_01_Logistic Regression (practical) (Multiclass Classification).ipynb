# %%
# Data Manipulation Libraries
import pandas as pd 

# Data Visualization Libraries 
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings 

# Machine Learning Libraries 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# Others 
sns.set_style("darkgrid")
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r"H:\Programming\Files\Machine Learning\Files\Iris.csv")
df.head(3)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %% [markdown]
# # Data Understanding

# %%
print("Info:")
print(df.info())
print("\nNull Values:")
print(df.isnull().sum())
print("\nDuplicate:")
print(df.duplicated().sum())
# Out:
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# None
#
# Null Values:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64
#
# Duplicate:
# 0

# %% [markdown]
# # Data Cleaning

# %%
df.drop(columns=["Id"], inplace=True)
df.head(3)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
sns.pairplot(df)
plt.show()

# %%
sns.pairplot(df, hue="Species")
plt.show()

# %%
df.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# # Model Evaluation

# %%
x = df.iloc[:,:-1]
y = df['Species']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)
print("Successfully completed.")
# Out:
# Successfully completed.

# %% [markdown]
# # LogisticRegression

# %%
# multi_class : {'auto', 'ovr', 'multinomial'}, default='auto'

# %% [markdown]
# ## OVR

# %%
lr_ovr = LogisticRegression(multi_class="ovr")
lr_ovr.fit(x_train,y_train)
# Out:
# LogisticRegression(multi_class='ovr')

# %%
lr_ovr.score(x_test,y_test)*100
# Out:
# 96.66666666666667

# %% [markdown]
# ## Multinomial

# %%
lr_mul = LogisticRegression(multi_class="multinomial")
lr_mul.fit(x_train,y_train)
# Out:
# LogisticRegression(multi_class='multinomial')

# %%
lr_mul.score(x_test,y_test)*100
# Out:
# 100.0

# %% [markdown]
# ## Auto

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 100.0
